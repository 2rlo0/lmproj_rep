# %%
import langchain
langchain.__version__
# Out:
# '0.3.27'

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model='gpt-4o-mini')
llm
# Out:
# ChatOpenAI(client=<openai.resources.chat.completions.completions.Completions object at 0x00000187ED8E1E80>, async_client=<openai.resources.chat.completions.completions.AsyncCompletions object at 0x00000187EDD9FF20>, root_client=<openai.OpenAI object at 0x00000187EC25C6E0>, root_async_client=<openai.AsyncOpenAI object at 0x00000187ED8E3E60>, model_name='gpt-4o-mini', model_kwargs={}, openai_api_key=SecretStr('**********'))

# %%
messages = [
    ("system", "당신은 서울의 음식과 문화 전문가입니다."),
    ("human","서울을 대표하는 음식을 맛볼 수 있는 레스토랑 5개를 추천해 주세요.")
]
res = llm.invoke(messages)

# %%
res # 객체가 다름 ai 메시지가 객체 안에 바로 들어 있음 -> 추상화
# Out:
# AIMessage(content='서울에서 대표적인 한국 음식을 맛볼 수 있는 레스토랑 5곳을 추천해 드립니다.\n\n1. **광장시장 (Gwangjang Market)**  \n   - 다양한 한국 전통 음식을 맛볼 수 있는 곳으로, 빈대떡, 만두, 육회 등이 인기입니다. 시장 내 여러 포장마차에서 즉석에서 조리한 음식을 즐길 수 있습니다.\n\n2. **토속촌 (Tosokchon)**  \n   - 유명 한식당으로, 제주도의 흑돼지와 전통 삼계탕이 특히 맛있습니다. 품질 높은 재료로 만든 국물과 고소한 맛이 일품입니다.\n\n3. **교동짬뽕 (Gyodong Jjamppong)**  \n   - 해물 짬뽕과 짜장면이 유명한 중국 음식점이지만, 한국식 짬뽕은 서울에서 특색 있는 맛으로 많은 사랑을 받고 있습니다. 매운 국물과 풍성한 해물로 구성된 메뉴가 일품입니다.\n\n4. **한일관 (Hanilkwan)**  \n   - 전통 한정식 코스 요리를 제공하는 곳으로, 다양한 반찬과 함께 제공되는 정갈한 한상이 특징입니다. 한국의 전통적인 식사 문화를 경험할 수 있습니다.\n\n5. **백년옥 (Baeknyeonok)**  \n   - 유명한 순두부찌개 전문점으로, 신선한 재료로 만든 순두부와 매콤한 국물이 조화를 이룹니다. 간편한 한 끼로 남녀노소 모두가 좋아하는 메뉴입니다.\n\n이들 레스토랑에서는 서울의 다양한 전통 음식을 맛보실 수 있으며, 한국의 맛과 문화를 잘 느낄 수 있습니다.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 385, 'prompt_tokens': 43, 'total_tokens': 428, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-C7Cje4s8QarfX7WYyFA1Pxuu4pn9u', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--994d7a1b-7cd8-49f0-8da7-175d9e9a2c51-0', usage_metadata={'input_tokens': 43, 'output_tokens': 385, 'total_tokens': 428, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
res.content
# Out:
# '서울에서 대표적인 한국 음식을 맛볼 수 있는 레스토랑 5곳을 추천해 드립니다.\n\n1. **광장시장 (Gwangjang Market)**  \n   - 다양한 한국 전통 음식을 맛볼 수 있는 곳으로, 빈대떡, 만두, 육회 등이 인기입니다. 시장 내 여러 포장마차에서 즉석에서 조리한 음식을 즐길 수 있습니다.\n\n2. **토속촌 (Tosokchon)**  \n   - 유명 한식당으로, 제주도의 흑돼지와 전통 삼계탕이 특히 맛있습니다. 품질 높은 재료로 만든 국물과 고소한 맛이 일품입니다.\n\n3. **교동짬뽕 (Gyodong Jjamppong)**  \n   - 해물 짬뽕과 짜장면이 유명한 중국 음식점이지만, 한국식 짬뽕은 서울에서 특색 있는 맛으로 많은 사랑을 받고 있습니다. 매운 국물과 풍성한 해물로 구성된 메뉴가 일품입니다.\n\n4. **한일관 (Hanilkwan)**  \n   - 전통 한정식 코스 요리를 제공하는 곳으로, 다양한 반찬과 함께 제공되는 정갈한 한상이 특징입니다. 한국의 전통적인 식사 문화를 경험할 수 있습니다.\n\n5. **백년옥 (Baeknyeonok)**  \n   - 유명한 순두부찌개 전문점으로, 신선한 재료로 만든 순두부와 매콤한 국물이 조화를 이룹니다. 간편한 한 끼로 남녀노소 모두가 좋아하는 메뉴입니다.\n\n이들 레스토랑에서는 서울의 다양한 전통 음식을 맛보실 수 있으며, 한국의 맛과 문화를 잘 느낄 수 있습니다.'

# %%
messages = [
    [("system", "당신은 서울의 음식 전문가입니다."), ("human","서울을 대표하는 음식점 5개를 추천해 주세요.")],
    [("system", "당신은 서울의 문화 전문가입니다."), ("human","서울에서 친구랑 놀러가보기 좋은 곳 5개를 추천해 주세요.")]
]
response = llm.batch(messages)
response
# Out:
# [AIMessage(content="서울은 다양한 음식 문화가 발달해 있어 많은 훌륭한 음식점이 있습니다. 아래는 서울을 대표하는 음식점 5곳을 추천드립니다.\n\n1. **한남동 '정식당'**\n   - 현대적인 한국 요리를 제공하는 고급 음식점으로, 섬세한 맛과 창의적인 플레이팅으로 유명합니다. 신선한 재료를 사용해 계절마다 변하는 메뉴는 미식가들 사이에서 인기가 높습니다.\n\n2. **광장시장 '마포할매옥수수국수'**\n   - 전통 한국의 길거리 음식과 소박한 한국식 국수 요리를 맛볼 수 있는 자리입니다. 특히 옥수수 국수와 김밥은 많은 사랑을 받고 있으며, 분위기와 친절한 서비스도 매력적입니다.\n\n3. **명동 '부산교차로'**\n   - 부산 갑오징어 초계탕으로 유명한 식당으로, 해산물과 신선한 재료로 만들어진 음식을 즐길 수 있습니다. 매력적인 해산물 요리와 함께 다양한 안주도 있어 술과 곁들이기 좋습니다.\n\n4. **종로 '광화문 미진'**\n   - 전통 한국 비빔밥과 국수를 전문으로 하는 곳으로, 복잡한 현대적 요리보다 정통 한국의 맛을 중시합니다. 샤프한 스프와 함께 이곳의 비빔밥은 꼭 시도해볼 만한 메뉴입니다.\n\n5. **홍대 '이태원 갈비'**\n   - 이태원 지역의 전통적인 한식 고기집으로, 숙성된 갈비와 다양한 반찬이 인상적입니다. 식당 내부의 아늑한 분위기와 함께 고기 요리를 즐기실 수 있습니다.\n\n이 음식점들은 각기 다른 매력을 가지고 있어, 서울을 방문하신다면 꼭 한번 들러보시기를 권장합니다!", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 426, 'prompt_tokens': 34, 'total_tokens': 460, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-C7CpxWgsqNeloIGXshbljKp5MG0sV', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--47edfb97-2040-4647-aace-51c5b05f1e73-0', usage_metadata={'input_tokens': 34, 'output_tokens': 426, 'total_tokens': 460, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  AIMessage(content='서울에서 친구랑 놀러가기에 좋은 곳 5곳을 추천해드릴게요!\n\n1. **홍대**: 홍대 지역은 젊은이들이 많이 모이는 곳으로 다양한 카페, 음식점, 바가 밀집해 있습니다. 거리 공연과 예술 작품도 많이 볼 수 있어 활기찬 분위기를 느낄 수 있습니다. 특히 홍대 걷고싶은거리에서는 다양한 문화와 개성 넘치는 상점들을 구경할 수 있어요.\n\n2. **이태원**: 이태원은 다양한 문화가 공존하는 다국적 거리로, 맛있는 국제 음식과 독특한 바들이 많습니다. 이외에도 이태원 해밀턴 호텔 근처에는 다양한 엔터테인먼트 시설과 클럽이 있어 밤문화도 즐길 수 있습니다.\n\n3. **남산서울타워**: 남산에 위치한 서울타워는 서울 시내를 한눈에 볼 수 있는 전망대입니다. 케이블카를 타고 올라가며 아름다운 경치를 감상할 수 있고, 타워 주변의 공원에서 산책도 즐길 수 있습니다.\n\n4. **가로수길**: 신사동에 위치한 가로수길은 세련된 카페와 부티크가 있는 거리입니다. 트렌디한 분위기에서 쇼핑과 브런치를 즐기기에 좋은 장소로, 특히 여름에는 가로수를 따라 산책하는 것도 즐겁습니다.\n\n5. **북촌 한옥마을**: 전통 한옥이 밀집해 있는 북촌 한옥마을은 한국의 전통 문화를 체험할 수 있는 장소입니다. 한옥을 구경하며 사진을 찍거나 전통 찻집에서 차를 즐길 수 있는 좋은 곳입니다. 이곳은 조용하고 한적한 분위기여서 친구와의 대화도 편안하게 나눌 수 있습니다.\n\n이 외에도 서울에는 다양한 매력적인 장소가 많으니, 기분에 따라 여러 곳을 탐방해보시길 추천합니다!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 440, 'prompt_tokens': 38, 'total_tokens': 478, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-mini-2024-07-18', 'system_fingerprint': 'fp_560af6e559', 'id': 'chatcmpl-C7CpwoqV9ELJWzxh0t6etrWEJo8cq', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='run--2cf6afe6-0c9b-488c-acad-e34c29d60c3d-0', usage_metadata={'input_tokens': 38, 'output_tokens': 440, 'total_tokens': 478, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]

# %%
for res in response:
    print(res.content)
# Out:
# 서울은 다양한 음식 문화가 발달해 있어 많은 훌륭한 음식점이 있습니다. 아래는 서울을 대표하는 음식점 5곳을 추천드립니다.
#
# 1. **한남동 '정식당'**
#    - 현대적인 한국 요리를 제공하는 고급 음식점으로, 섬세한 맛과 창의적인 플레이팅으로 유명합니다. 신선한 재료를 사용해 계절마다 변하는 메뉴는 미식가들 사이에서 인기가 높습니다.
#
# 2. **광장시장 '마포할매옥수수국수'**
#    - 전통 한국의 길거리 음식과 소박한 한국식 국수 요리를 맛볼 수 있는 자리입니다. 특히 옥수수 국수와 김밥은 많은 사랑을 받고 있으며, 분위기와 친절한 서비스도 매력적입니다.
#
# 3. **명동 '부산교차로'**
#    - 부산 갑오징어 초계탕으로 유명한 식당으로, 해산물과 신선한 재료로 만들어진 음식을 즐길 수 있습니다. 매력적인 해산물 요리와 함께 다양한 안주도 있어 술과 곁들이기 좋습니다.
#
# 4. **종로 '광화문 미진'**
#    - 전통 한국 비빔밥과 국수를 전문으로 하는 곳으로, 복잡한 현대적 요리보다 정통 한국의 맛을 중시합니다. 샤프한 스프와 함께 이곳의 비빔밥은 꼭 시도해볼 만한 메뉴입니다.
#
# 5. **홍대 '이태원 갈비'**
#    - 이태원 지역의 전통적인 한식 고기집으로, 숙성된 갈비와 다양한 반찬이 인상적입니다. 식당 내부의 아늑한 분위기와 함께 고기 요리를 즐기실 수 있습니다.
#
# 이 음식점들은 각기 다른 매력을 가지고 있어, 서울을 방문하신다면 꼭 한번 들러보시기를 권장합니다!
# 서울에서 친구랑 놀러가기에 좋은 곳 5곳을 추천해드릴게요!
#
# 1. **홍대**: 홍대 지역은 젊은이들이 많이 모이는 곳으로 다양한 카페, 음식점, 바가 밀집해 있습니다. 거리 공연과 예술 작품도 많이 볼 수 있어 활기찬 분위기를 느낄 수 있습니다. 특히 홍대 걷고싶은거리에서는 다양한 문화와 개성 넘치는 상점들을 구경할 수 있어요.
#
# 2. **이태원**: 이태원은 다양한 문화가 공존하는 다국적 거리로, 맛있는 국제 음식과 독특한 바들이 많습니다. 이외에도 이태원 해밀턴 호텔 근처에는 다양한 엔터테인먼트 시설과 클럽이 있어 밤문화도 즐길 수 있습니다.
#
# 3. **남산서울타워**: 남산에 위치한 서울타워는 서울 시내를 한눈에 볼 수 있는 전망대입니다. 케이블카를 타고 올라가며 아름다운 경치를 감상할 수 있고, 타워 주변의 공원에서 산책도 즐길 수 있습니다.
#
# 4. **가로수길**: 신사동에 위치한 가로수길은 세련된 카페와 부티크가 있는 거리입니다. 트렌디한 분위기에서 쇼핑과 브런치를 즐기기에 좋은 장소로, 특히 여름에는 가로수를 따라 산책하는 것도 즐겁습니다.
#
# 5. **북촌 한옥마을**: 전통 한옥이 밀집해 있는 북촌 한옥마을은 한국의 전통 문화를 체험할 수 있는 장소입니다. 한옥을 구경하며 사진을 찍거나 전통 찻집에서 차를 즐길 수 있는 좋은 곳입니다. 이곳은 조용하고 한적한 분위기여서 친구와의 대화도 편안하게 나눌 수 있습니다.
#
# 이 외에도 서울에는 다양한 매력적인 장소가 많으니, 기분에 따라 여러 곳을 탐방해보시길 추천합니다!

# %%
messages=[
    ("system", "당신은 서울의 음식과 문화 전문가입니다"),
    ("human", "서울을 대표하는 음식을 맛볼 수 있는 레스토랑 5개를 추천해 주세요")

]
response=llm.stream(messages)
for res in response:
    print(res.content, end='')
# Out:
# 서울에는 전통 한국 음식을 맛볼 수 있는 훌륭한 레스토랑들이 많이 있습니다. 아래는 서울을 대표하는 음식을 즐길 수 있는 추천 레스토랑 5곳입니다.
#
# 1. **광장시장 (Gwangjang Market)**
#    - **추천 메뉴**: 비빔밥, 전 (전통 한국식 팬케이크)
#    - 광장시장은 한국의 전통 시장으로, 다양한 음식을 즐길 수 있습니다. 특히 비빔밥과 고소한 전을 현지에서 맛보는 것이 좋습니다.
#
# 2. **한일관 (Hanilkwan)**
#    - **추천 메뉴**: 불고기, 갈비
#    - 한일관은 전통적인 한국식 고기 요리를 전문으로 하는 레스토랑으로, 맛있고 부드러운 불고기와 갈비로 유명합니다. 고급스러운 분위기에서 식사를 즐길 수 있습니다.
#
# 3. **부엌 (BooK)**
#    - **추천 메뉴**: 한정식
#    - 부엌은 다양한 반찬과 메인 요리가 함께 제공되는 전통 한정식을 맛볼 수 있는 곳입니다. 정갈한 플레이팅과 신선한 재료로 질 높은 식사를 제공합니다.
#
# 4. **삼청동 수제비 (Samcheong-dong Sujebi)**
#    - **추천 메뉴**: 수제비
#    - 유명한 수제비 전문점으로, 쫄깃한 수제비와 따뜻한 국물의 조화가 일품입니다. 편안한 분위기 속에서 한국 전통의 맛을 즐길 수 있습니다.
#
# 5. **계산소 (Gyeyangso)**
#    - **추천 메뉴**: 조기구이, 생선조림
#    - 계산소는 신선한 해산물 요리를 전문으로 하는 레스토랑으로, 특히 조기구이와 생선조림이 인기입니다. 한국의 바다 맛을 느낄 수 있는 좋은 장소입니다.
#
# 이 레스토랑들은 서울의 전통 맛을 즐기기에 좋은 곳들이니, 꼭 방문해 보세요!

# %% [markdown]
# # async, sync

# %%
import asyncio
import time

async def invoke_async(llm, messages):
    response = await llm.ainvoke(messages)
    print(response.content)

async def invoke_parallel(llm, messages):
    tasks = [invoke_async(llm, messages) for _ in range(10)]
    await asyncio.gather(*tasks)

# %%
messages=[
    ("system", "당신은 서울의 음식과 문화 전문가입니다"),
    ("human", "서울을 대표하는 음식을 맛볼 수 있는 레스토랑 5개를 추천해 주세요")

]
start = time.perf_counter()

await invoke_parallel(llm, messages)

end = time.perf_counter()

print(f'Elapsed time : {end - start:.2f} seconds')
# Out:
# 서울에서 대표적인 음식을 맛볼 수 있는 레스토랑 5곳을 추천해 드리겠습니다.
#
# 1. **광장시장 (Gwangjang Market)**
#    - 서울의 전통 시장으로, 빈대떡, 육회, 돌솥비빔밥 등 다양한 한국 음식을 맛볼 수 있습니다. 특히 너무 유명한 빈대떡과 막걸리를 꼭 드셔보세요.
#
# 2. **을지로 입구에 위치한 "명동교자" (Myeongdong Kyoja)**
#    - 유명한 칼국수와 만두를 제공합니다. 쫄깃한 면발과 진한 국물 맛이 일품입니다. 점심 또는 저녁에 대기할 수 있지만, 그만큼 가치가 있습니다.
#
# 3. **삼청동의 "신선설농탕" (Sinseon Seolleongtang)**
#    - 서울의 대표적인 설렁탕 레스토랑입니다. 깊은 맛의 국물과 부드러운 고기가 어우러져 환상적인 조화를 이룹니다.
#
# 4. **강남의 "주옥" (Jueok)**
#    - 고급 한정식을 맛볼 수 있는 곳으로, 정갈한 비주얼과 함께 전통적인 한국의 맛을 경험할 수 있습니다. 특별한 날에 추천드립니다.
#
# 5. **홍대의 "베이글과 집" (Bagel & House)**
#    - 다양한 한국식 브런치 메뉴와 함께 고소한 베이글을 제공합니다. 한국의 전통 간식과 현대적인 분위기를 동시에 느낄 수 있습니다.
#
# 이 레스토랑들은 각기 다른 매력으로 서울의 전통 음식을 맛볼 수 있는 좋은 장소들입니다. 즐거운 식사 되세요!
# 서울에는 다양한 전통 음식과 현대적인 해석이 가미된 요리를 즐길 수 있는 레스토랑들이 많이 있습니다. 다음은 서울을 대표하는 음식을 맛볼 수 있는 추천 레스토랑 5곳입니다.
#
# 1. **광장시장 (Gwangjang Market)**
#    - **추천 메뉴**: 빈대떡, 족발, 김치전
#    - 광장시장은 서울의 대표적인 전통 시장으로, 다양한 간식과 음식을 한 곳에서 즐길 수 있습니다. 특히 빈대떡과 족발이 유명합니다.
#
# 2. **바우네 한국식당 (Baune Korean Restaurant)**
#    - **추천 메뉴**: 비빔밥, 불고기
#    - 전통 비빔밥과 불고기를 맛볼 수 있는 곳으로, 신선한 재료와 정갈한 맛이 일품입니다.
#
# 3. **겐지 (Genji)**
#    - **추천 메뉴**: 철판구이, 쌈밥
#    - 현대적인 감각으로 해석한 한식을 제공하며, 특히 철판구이와 함께 제공되는 쌈밥이 인기입니다.
#
# 4. **명동교자 (Myeongdong Kyoja)**
#    - **추천 메뉴**: 물만두, 칼국수
#    - 명동에서 유명한 칼국수 전문점으로, 쫄깃한 칼국수와 수제 물만두가 인상적입니다.
#
# 5. **삼청동 수제비 (Samcheongdong Sujebi)**
#    - **추천 메뉴**: 수제비, 갈비찜
#    - 수제비와 갈비찜이 유명한 집으로, 깊고 진한 국물 맛이 매력적입니다.
#
# 이 외에도 서울은 다양한 지역 음식을 경험할 수 있는 레스토랑이 많으니, 자신이 선호하는 스타일에 맞게 선택해보세요!
# 서울에서 대표적인 음식을 맛볼 수 있는 레스토랑 다섯 곳을 추천해 드리겠습니다.
#
# 1. **명동교자**
#    - 대표 음식: 칼국수
#    - 위치: 명동
#    - 설명: 이곳의 칼국수는 쫄깃한 면발과 풍부한 국물 맛이 일품입니다. 만두도 유명해 함께 즐기기 좋은 곳입니다.
#
# 2. **조계사 토속촌**
#    - 대표 음식: 삼계탕
#    - 위치: 종로
#    - 설명: 전통적인 삼계탕을 제공하는 이곳은 촉촉한 찜닭의 맛과 함께 닭 속에 찹쌀과 인삼이 가득합니다.
#
# 3. **을지로 골뱅이**
#    - 대표 음식: 골뱅이무침
#    - 위치: 을지로
#    - 설명: 신선한 골뱅이를 사용한 골뱅이무침이 맛있으며, 쭈꾸미나 막걸리와 함께 즐기기 좋습니다.
#
# 4. **한양집**
#    - 대표 음식: 불고기
#    - 위치: 명동
#    - 설명: 전통적인 방법으로 조리한 불고기를 즐길 수 있는 곳으로, 담백하고 달콤한 맛이 특징입니다.
#
# 5. **광장시장**
#    - 대표 음식: 빈대떡과 마약김밥
#    - 위치: 종로
#    - 설명: 다양한 먹거리를 제공하는 이 시장에서 빈대떡과 마약김밥을 맛보는 것은 필수입니다. 시장의 활기와 함께 다양한 음식을 경험할 수 있습니다.
#
# 이 모든 식당들은 서울의 다양한 매력을 잘 표현하고 있으니 방문해 보시면 좋겠습니다!
# 서울에서 대표적인 음식을 맛볼 수 있는 레스토랑 5곳을 추천해 드릴게요.
#
# 1. **광장시장 통닭**
#    - **특징**: 광장시장에서 유명한 통닭으로, 시 crispy한 튀김옷과 촉촉한 속살이 일품입니다. 바삭한 튀김과 함께 제공되는 매콤한 양념치킨이 인기입니다.
#
# 2. **마포갈매기**
#    - **특징**: 서울의 대표적인 갈비집으로, 질좋은 고기를 숯불에 구워내어 쌈장과 함께 먹는 풍미가 특별합니다. 고기를 좋아하는 분들께는 최고의 선택이 될 것입니다.
#
# 3. **부암동 소머리국밥**
#    - **특징**: 깊고 진한 육수의 소머리국밥을 전문으로 하는 식당으로, 비린내 없이 깔끔하고 진한 맛이 매력입니다. 밥은 육수와 함께 제공되어 고소한 맛을 느낄 수 있습니다.
#
# 4. **서래마을 한식당**
#    - **특징**: 전통 한식을 현대적으로 재해석한 레스토랑으로, 다양한 반찬과 함께 정갈한 메인 요리를 제공합니다. 특히, 비빔밥과 전통 한정식이 인기입니다.
#
# 5. **돈까스 101**
#    - **특징**: 일본식 돈까스를 한국식으로 변형한 메뉴로, 두툼한 고기와 바삭한 튀김옷이 특징입니다. 다양한 소스와 곁들이는 반찬들이 잘 어울립니다.
#
# 이 레스토랑들은 서울의 다양한 식문화를 경험할 수 있는 좋은 장소입니다. 예약이나 대기 시간 등을 고려해 미리 계획하시기 바랍니다. 즐거운 식사 되세요!
# 서울에서 대표적인 음식을 맛볼 수 있는 레스토랑 5곳을 추천해 드립니다:
#
# 1. **광장시장** - 전통 시장에서 한 끼를 즐길 수 있는 곳으로, 다양한 한국 전통 음식을 맛볼 수 있습니다. 특히 김밥, 떡볶이, 빈대떡, 순대 등을 추천합니다. 시장 분위기 속에서 여러 음식을 간편하게 시식할 수 있어 관광객들에게도 인기가 많습니다.
#
# 2. **명동교자** - 서울에서 유명한 칼국수 전문점으로, 진한 육수의 칼국수와 만두가 유명합니다. 쫄깃한 면과 함께 곁들이는 김치와 육수의 조화가 일품입니다.
#
# 3. **삼청동 수제비** - 삼청동에 위치한 전통 한국 음식점으로, 시원한 국물의 수제비가 유명합니다. 질 좋은 재료로 만드는 수제비는 부드럽고 쫄깃하며 국물 맛이 깊습니다.
#
# 4. **을지로 골뱅이** - 골뱅이 무침과 소주를 즐길 수 있는 곳으로, 아늑한 분위기에서 맛있는 전통 안주와 함께 한국의 소주 문화를 경험할 수 있습니다. 특히 신선한 골뱅이와 매콤한 소스가 조화롭게 어우러져 많은 사랑을 받고 있습니다.
#
# 5. **한남동 이태리** - 이 곳에서는 한국 전통 음식을 현대적으로 재해석한 메뉴를 선보입니다. 한식의 맛을 그대로 유지하면서도 다양한 퓨전 요리를 경험할 수 있는 곳으로, 새로운 경험을 원하는 분들에게 추천합니다.
#
# 이곳들은 서울의 다양한 음식 문화를 경험할 수 있는 훌륭한 장소들입니다. 각 레스토랑의 특별한 맛을 즐겨 보세요!
# 서울에서 전통적인 한국 음식을 제대로 맛볼 수 있는 레스토랑 5곳을 추천해 드립니다.
#
# 1. **광화문 미진**
#    - 위치: 광화문
#    - 추천 메뉴: 비빔밥, 김치찌개
#    - 설명: 정갈한 비빔밥과 깊은 맛의 김치찌개로 유명하며, 역사적인 장소인 광화문 근처에 위치하고 있어 관광과 함께 식사를 즐기기 좋습니다.
#
# 2. **삼청동 수제비**
#    - 위치: 삼청동
#    - 추천 메뉴: 수제비, 칼국수
#    - 설명: 시원한 국물의 수제비와 손으로 직접 만든 칼국수가 메인 메뉴인 이곳은 전통적인 한식의 깊은 맛을 느낄 수 있습니다.
#
# 3. **부암동 한정식**
#    - 위치: 부암동
#    - 추천 메뉴: 한정식 세트
#    - 설명: 다양한 반찬과 함께 제공되는 한정식은 한국 전통의 미를 느낄 수 있는 메뉴입니다. 고즈넉한 분위기에서 여유롭게 한식을 즐길 수 있습니다.
#
# 4. **종로의 본가**
#    - 위치: 종로
#    - 추천 메뉴: 불고기, 갈비찜
#    - 설명: 전통적인 불고기와 갈비찜 전문점으로, 푸짐한 양과 함께 고소한 맛을 자랑합니다. 세련된 인테리어와 함께 좋은 식사를 즐길 수 있습니다.
#
# 5. **명동교자**
#    - 위치: 명동
#    - 추천 메뉴: 칼국수, 만두
#    - 설명: 명동에 위치한 칼국수 전문점으로, 쫄깃한 면과 진한 국물 맛이 일품입니다. 만두와 함께 먹으면 더욱 풍미가 가득해집니다.
#
# 각 레스토랑은 독특한 매력을 가지고 있으며, 서울의 다양한 음식을 경험할 수 있는 좋은 장소입니다. 즐거운 식사 되세요!
# 서울에서 대표적인 음식을 즐길 수 있는 레스토랑 5곳을 추천해 드립니다:
#
# 1. **광화문 한식당 (Gwanghwamun Hanok)**: 전통 한옥 스타일의 레스토랑으로, 한식 코스 요리를 특히 잘 제공하는 곳입니다. 비빔밥, 김치찌개, 그리고 제철 재료를 활용한 다양한 한식 메뉴를 맛볼 수 있습니다.
#
# 2. **이태원 참살이 (Itaewon Chamssal-i)**: 이곳은 전통 한우를 전문으로 하는 고기집으로, 질 좋은 한우를 다양한 방식으로 즐길 수 있습니다. 특별한 숙성 과정을 거친 한우 불고기나 갈비를 추천합니다.
#
# 3. **부산어묵 (Busan Eomuk)**: 명동에 위치한 어묵 전문점입니다. 부산의 전통 어묵이 서울에서도 맛볼 수 있으며, 뜨끈한 오뎅 국물과 함께 다양한 어묵 제품을 즐길 수 있습니다.
#
# 4. **매봉에서 (Maebongeseo)**: 서울의 전통 비빔밥을 대표하는 곳 중 하나로, 신선한 재료로 만든 비빔밥과 돌솥 비빔밥이 인기입니다. 정통 맛을 추구하는 식사로 추천합니다.
#
# 5. **우래옥 (Woori Restaurant)**: 서울에서 유명한 평양냉면 전문점으로, 시원하고 깊은 맛의 육수가 특징입니다. 자르기와 비벼먹는 방식으로 맛볼 수 있는 냉면은 특히 여름에 인기가 많습니다.
#
# 이 외에도 서울에는 다양한 지역 특산물과 전통 음식을 맛볼 수 있는 곳들이 많으니, 기회가 된다면 여러 곳을 방문해보시길 권장합니다!
# 서울에서 대표적인 음식을 맛볼 수 있는 레스토랑 다섯 곳을 추천해드릴게요.
#
# 1. **광장시장** - **빈대떡**
#    - 광장시장은 한국 전통 시장으로, 다양한 음식을 즐길 수 있습니다. 그중에서도 빈대떡과 함께 막걸리를 즐기는 것이 유명합니다. 특히, 빈대떡을 만들 때 사용되는 재료의 신선함과 정통성이 돋보입니다.
#
# 2. **명동교자** - **칼국수**
#    - 명동에 위치한 명동교자는 칼국수로 유명한 곳입니다. 직접 만든 면과 깊고 진한 국물 맛이 일품인 칼국수를 제공하며, 만두도 함께 즐길 수 있습니다. 특히 관광객들에게 인기가 많습니다.
#
# 3. **삼청동 수제비** - **수제비**
#    - 삼청동에 위치한 이곳은 수제비가 맛있는 집으로 알려져 있습니다. 손으로 만든 쫄깃한 수제비와 함께 깊은 국물 맛을 경험할 수 있으며, 아늑한 분위기에서 식사를 할 수 있습니다.
#
# 4. **부암동 쌈지길** - **전통 한식**
#    - 부암동 쌈지길에는 여러 가지 한식 레스토랑이 모여 있습니다. 이곳에서 한정식이나 전통적인 한식을 맛볼 수 있으며, 고즈넉한 분위기에서 식사를 즐길 수 있습니다.
#
# 5. **이태원 남산돈까스** - **돈까스**
#    - 이태원에 위치한 남산돈까스는 돈까스 전문점으로 유명합니다. 바삭한 튀김옷과 부드러운 고기의 조화가 일품이며, 다양한 사이드 메뉴도 함께 제공됩니다.
#
# 이 외에도 서울에는 맛있는 음식과 다양한 레스토랑이 많으니, 기회를 이용해 여러 곳을 탐방해보세요!
# 서울에서 전통적인 한국 음식을 맛볼 수 있는 레스토랑 5곳을 추천해 드리겠습니다.
#
# 1. **계림정** (Gyerimjeong)
#    - **주소:** 서울 종로구
#    - **추천 메뉴:** 한정식
#    - **특징:** 전통 한정식을 제공하는 이곳은 다양한 요리를 작은 접시에 나눠서 제공해, 한국의 다양한 맛을 한번에 경험할 수 있습니다. 고급스러운 분위기와 함께 한국 전통 음식을 즐길 수 있습니다.
#
# 2. **세븐스 프레시** (Seven's Fresh)
#    - **주소:** 서울 강남구
#    - **추천 메뉴:** 불고기
#    - **특징:** 신선한 재료를 사용하여 고급스러운 불고기를 제공합니다. 스테이크처럼 구운 불고기를 여러 반찬과 함께 즐길 수 있으며, 고급스러운 분위기를 느낄 수 있습니다.
#
# 3. **명동교자** (Myeongdong Kyoja)
#    - **주소:** 서울 중구 명동
#    - **추천 메뉴:** 칼국수, 만두
#    - **특징:** 서울에서 유명한 칼국수 전문점으로, 직접 만든 손칼국수와 만두가 인기입니다. 간편하면서도 맛있는 한국 대표 음식을 즐길 수 있는 곳입니다.
#
# 4. **수라상** (Surasang)
#    - **주소:** 서울 강서구
#    - **추천 메뉴:** 한식 뷔페
#    - **특징:** 다양한 한국 음식을 한자리에서 맛볼 수 있는 뷔페 형식의 레스토랑으로, 전통적인 한식을 현대적으로 재해석한 요리들을 제공합니다. 가족 단위 또는 여러 명이 함께 가기 좋은 장소입니다.
#
# 5. **조선식당** (Joseon Restaurant)
#    - **주소:** 서울 종로구
#    - **추천 메뉴:** 전통 찜, 탕
#    - **특징:** 전통 한국 음식을 현대적인 감각으로 재해석하여 제공하는 곳으로, 특히 각종 찜과 전통 탕의 맛이 일품입니다. 옛스러운 분위기 속에서 특별한 식사를 즐길 수 있습니다.
#
# 서울에서 다양한 한국 음식을 즐기실 수 있는 좋은 선택지들입니다. 각 레스토랑의 분위기와 메뉴의 특색을 살펴보시고 방문해 보시길 추천드립니다!
# 서울에서 대표적인 한국 음식을 맛볼 수 있는 레스토랑 5곳을 추천해 드립니다!
#
# 1. **광장시장 (Gwangjang Market)**
#    - **추천 메뉴**: 빈대떡, 마른안주, 쫄면
#    - 서울의 전통 시장인 광장시장은 다양한 한국 전통 음식을 한 곳에서 맛볼 수 있는 명소입니다. 특히 빈대떡과 함께 먹는 막걸리는 필수입니다.
#
# 2. ** 을지로 골뱅이집 (Euljiro Golbaengi)**
#    - **추천 메뉴**: 골뱅이 무침, 소주
#    - 을지로에 위치한 이곳은 신선한 골뱅이를 이용한 무침이 유명합니다. 소주와 함께하는 이 안주는 저녁에 친구들과 즐기기 좋은 메뉴입니다.
#
# 3. **한우명가 (Hanwoo Myungga)**
#    - **추천 메뉴**: 한우 스테이크, 갈비
#    - 한우의 고급스러운 맛을 체험할 수 있는 식당으로, 부드럽고 풍미가 뛰어난 한우를 제공하는 곳입니다. 고기 요리와 함께 밑반찬도 푸짐하게 나옵니다.
#
# 4. **신촌 할머니 국수 (Sinchon Halmeoni Guksu)**
#    - **추천 메뉴**: 잔치국수, 비빔국수
#    - 서울 신촌에 위치한 이 작은 식당은 잔치국수와 비빔국수로 유명합니다. 따뜻한 국물과 신선한 재료로 만든 국수가 매력적입니다.
#
# 5. **부엌에서 (Bueokeseo)**
#    - **추천 메뉴**: 김치찌개, 제육볶음
#    - 전통적인 한식을 현대적인 분위기에서 즐길 수 있는 레스토랑입니다. 푸짐한 양과 정성으로 만든 한식 메뉴가 특징입니다.
#
# 이 다섯 곳에서 서울의 다양한 맛과 문화의 진수를 느껴보시길 바랍니다!
# Elapsed time : 12.67 seconds

# %%
# sync 호출 시간 비교 5 times
